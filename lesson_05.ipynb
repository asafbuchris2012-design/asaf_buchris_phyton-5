# %% [markdown]
# # Lesson 5 - while Loops
# In this lesson we'll learn:
#
# - What is a while loop
# - How to create loops with conditions
#  -Using break and continue
# - Input validation with loops
# - Avoiding infinite loops

# %% [markdown]
# ---
# ### Part 1: What is a Loop?
# A loop repeats code multiple times. The while loop continues as long as a condition is True.
# Syntax:

# %%
while condition:
    # code to repeat
    # this code runs while condition is True

# %% [markdown]
# Code cell:

# %%
# Simple while loop
count = 1

while count <= 5:
    print(f"Count is: {count}")
    count = count + 1

print("Loop finished!")

# %% [markdown]
# ---
# ### Part 2: Loop with User Input
# Code cell:

# %%
# Keep asking until user types "stop"
while True:
    answer = input("Type 'stop' to exit: ")
    
    if answer == "stop":
        break
    
    print("You typed:", answer)

print("Program ended")

# %% [markdown]
# ---
# ### Part 3: The break Statement
# The break statement exits the loop immediately.
# Code cell:

# %%
# Find first number divisible by 7
number = 1

while number <= 100:
    if number % 7 == 0:
        print(f"First number divisible by 7 is: {number}")
        break
    number = number + 1

# %% [markdown]
# ---
# ### Part 4: The continue Statement
# The continue statement skips to the next iteration.
# Code cell:

# %%
# Print only odd numbers from 1 to 10
number = 0

while number < 10:
    number = number + 1
    
    if number % 2 == 0:
        continue  # Skip even numbers
    
    print(number)

# %% [markdown]
# ---
# ### Part 5: Common Patterns
# Pattern 1: Counter

# %%
count = 0
while count < 5:
    print("Hello")
    count = count + 1

# %% [markdown]
# Pattern 2: User Input Validation

# %%
age = -1
while age < 0:
    age = int(input("Enter your age: "))
    if age < 0:
        print("Age cannot be negative!")

# %% [markdown]
# Pattern 3: Menu System

# %%
choice = ""
while choice != "quit":
    print("1. Option A")
    print("2. Option B")
    print("Type 'quit' to exit")
    choice = input("Choose: ")

# %% [markdown]
# ---
# ### Important Notes
#
# - The condition is checked before each iteration
# - Make sure the condition will eventually become False
# - Always update the variable in the condition to avoid infinite loops
# - Use break to exit early
# - Use continue to skip to next iteration

# %% [markdown]
# ---
# ### Practice Tasks

# %% [markdown]
# ### Task 1: Countdown
# Write a program that:
#
# - Starts from 10
# - Counts down to 1
# - Prints each number
# - Prints "Blast off!" at the end
#
# Code cell:

# %%
# Your code her
count = 10
while count <=10 :
    print(f"Countdown: {count}")
    if count == 0:
        print("blast off! ")
        break
    count = count - 1
# Out:
# Countdown: 10
# Countdown: 9
# Countdown: 8
# Countdown: 7
# Countdown: 6
# Countdown: 5
# Countdown: 4
# Countdown: 3
# Countdown: 2
# Countdown: 1
# Countdown: 0
# blast off!

# %% [markdown]
# ---
# ### Task 2: Sum Calculator
# Write a program that:
#
# - Asks the user to enter numbers
# - Keeps adding them to a total
# - Stops when user enters 0
# - Prints the final sum
#
# Code cell:

# %%
# Your code here
total = 0
while True:
   number = int(input("Enter a number to add to total: "))
   total = total + number
   print(total)
   if number == 0:
       break
# Out:
# 3
# 57
# 63
# 63

# %% [markdown]
# ---
# ### Task 3: Password Entry
# Write a program that:
#
# - Has a correct password (you choose it)
# - Keeps asking for the password
# - Gives the user 3 attempts
# - Prints "Access granted" or "Access denied"
#
# Code cell:

# %%
# Your code here
correct_password = "python"
attempts = 0
while attempts < 3:
    password = input("Enter the password: ")
    if password == correct_password:
        print("Access granted")
        break
    else:
        print("Incorrect password")
        attempts = attempts + 1
# Out:
# Incorrect password
# Incorrect password
# Access granted

# %% [markdown]
# ---
# ### Task 4: Guessing Game
# Write a number guessing game:
#
# - Computer picks a number between 1 and 10 (you choose it)
# - User keeps guessing
# - Give hints: "Too high" or "Too low"
# - When correct, print how many guesses it took
#
# Code cell:

# %%
# Your code here
secret_number = 7
guesses = 0
while True:
    guess = int(input("Guess the secret number (1-10): "))
    guesses = guesses + 1
    if guess == secret_number:
        print(f"Correct! You guessed it in {guesses} tries.")
        break
    elif guess > secret_number:
        print("too hige")
    else:
        print("too low")
# Out:
# too low
# too hige
# too hige
# Correct! You guessed it in 4 tries.

# %% [markdown]
# ---
# ### Task 5: Menu System
# Create a simple calculator menu:
#
# - Show options: 1-Add, 2-Subtract, 3-Multiply, 4-Divide, 5-Exit
# - Ask user to choose
# - If 1-4: ask for two numbers and show result
# - If 5: exit the program
# - Keep showing menu until user exits
#
# Code cell:

# %%
# Your code here
while True:
    user_input = int(input("Choose an option (1-add, 2-subtract, 3-multiply, 4-divide, 5-exit): "))
    if user_input == 5:
        print("Exiting the program.")
        break
    else:
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))
        if user_input == 1:
            print(f"Result: {num1 + num2}")
        elif user_input == 2:
            print(f"Result: {num1 - num2}")
        elif user_input == 3:
            print(f"Result: {num1 * num2}")
        elif user_input == 4:
            if num2 != 0:
                print(f"Result: {num1 / num2}")
            else:
                print("Error: Division by zero")
        else:
            print("Invalid option, please try again.")
# Out:
# Result: 28.0
# Exiting the program.

# %% [markdown]
# ---
# ### Task 6: Even Numbers Only (Challenge)
# Write a program that:
#
# - Asks the user to enter numbers
# - Only accepts even numbers
# - If odd, print "Only even numbers!" and ask again
# - Stops when user enters 0
# - Prints all the even numbers entered
#
# Code cell:

# %%
# Your code here
while True:
    user = int(input("Enter a number  "))
    if user % 2 != 0:
        print(" only Even numbers")
        continue
    elif user % 2 == 0 and user != 0:
        print(user)

    else:
        break

# %% [markdown]
# ---
# ### Advanced Challenge (Optional)
# Create a simple ATM simulation:
#
# 1. Start with balance of 1000
# 2. Menu options:
#
#     - Check balance
#     - Deposit money
#     - Withdraw money (check if enough balance)
#     - Exit
#
#
# 3. Keep running until user chooses exit
# 4. Validate all inputs (no negative numbers)
#
# Code cell:

# %%
# Your challenge code here
b1=0
balance = 1000
while True:
    user_input = input("check, deposit, withdraw, exit: ")
    if user_input == "check":
        print (f"Your balance is: ${balance}")
        b1+=1
    elif user_input == "deposit":
        amount = float(input("enter a number to deposit: "))
        balance+= amount
        b1+=1
        print (f"amount deposited: ${amount},you have a new balance of: ${balance}")
    elif user_input == "withdraw":
        amount = float(input("enter a number to withdraw: "))
        if amount <= balance:
            balance -= amount
        b1+=1
    elif amount > balance:
                print("insufficient funds")
                continue
    elif user_input == "exit":
        print("exiting")
        b1+=1 
        break
    print(f"you transacted {b1} times")
# Out:
# you transacted 0 times
# you transacted 1 times
# Your balance is: $800.0
# you transacted 2 times
# exiting

# %% [markdown]
# ---
# ### Lesson Summary
# What we learned today:
#
# - while loops repeat code while a condition is True
# - Loop structure: condition, indented code block, update variable
# - break exits the loop immediately
# - continue skips to the next iteration
# - Common uses: counters, user input validation, menu systems
#
# Important Warnings:
#
# - Always update the condition variable to avoid infinite loops
# - Test your loop with small numbers first
# - If stuck in infinite loop: click the stop button or restart kernel
#
# Next lesson: We'll learn about for loops and lists

# %% [markdown]
# ---
# ### Homework
#
# 1. Multiplication Table:
#
#     - Ask for a number
#     - Print its multiplication table from 1 to 10
#     - Use a while loop
#
#
# 2. Positive Numbers Only:
#
#     - Keep asking for numbers
#     - Only accept positive numbers
#     - Stop when user enters -1
#     - Print the average of all numbers entered
#
#
# 3. Simple Game:
#
#     - User starts with 100 points
#     - Each round: lose 5-15 random points (you choose)
#     - Keep playing while points > 0
#     - Print final score
#
#
#
# Code cell for homework:

# %%
# Space for your homework
#multipliction_table
while True:
    num = int(input("Enter a number to see its multiplication table (or 0 to exit): "))
    if num == 0:
        break
    elif num>=1 and num<=10:
        print(num*1)
        print(num*2)
        print(num*3)
        print(num*4)
        print(num*5)
        print(num*6)
        print(num*7)
        print(num*8)
        print(num*9)
        print(num*10)
    else:
        print("Please enter a number between 1 and 10.")
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30

# %%
#2
attempts = 0
while True: 
    num= int(input("enter a number"))
    if num == -1:
        break
    if num<0 and num != -1:
        print("negative numbers are not allowed")
    if num >0:
        attempts +=1

    attempts = int(attempts)
    
    avarage = num/attempts
    print(f"the avarage is {avarage}")

# %%
#3 simple game
score =  100
while True:
    lose = int(input("enter how many points to lose"))
    score -= lose
    print(f"your score in this round is {score}")
    if score <=0:
        print("game over")
        break
# Out:
# your score in this round is 77
# your score in this round is 32
# your score in this round is -35
# game over
